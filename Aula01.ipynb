# %%
# ex 1
frutas = ["morango", "banana", "uva"]
print(frutas)
# Out:
# ['morango', 'banana', 'uva']

# %%
frutas.append("kiwi")
print(frutas)
# Out:
# ['morango', 'banana', 'uva', 'kiwi']

# %%
# ex 2
livros = []
livros.append("O pequeno principe")
livros.append("Dom quixote")
livros.append("1984")
livro_removido = livros.pop()

# %%
print(f"Livros removidos {livro_removido}")
print(f"Pilha restante {livros}")
# Out:
# Livros removidos 1984
# Pilha restante ['O pequeno principe', 'Dom quixote']

# %%
# ex 3
clientes = []
clientes.append("ana")
clientes.append("Bruno")
clientes.append("Carla")
clientes.append("Daniel")
cliente_saiu = clientes.pop(0)
print(f"clientes que sairam: {cliente_saiu}")
print(f"Clientes restante: {clientes}")
# Out:
# clientes que sairam: ana
# Clientes restante: ['Bruno', 'Carla', 'Daniel']

# %%
#ex 4
contatos = {"ana": "1234-5678", "bruno": "9876-5432"}
contatos["carlos"] = "1122-3344"
print(f"para acessar o numero de ana:")
print(contatos["ana"])
# Out:
# para acessar o numero de ana:
# 1234-5678

# %%
# PJ 1
informacao = {}

def adicionar_contato(nome, numero, email):
    informacao[nome] = {"numero": numero, "email":email}
    print(f"{nome} adicionado com sucesso")


def buscar_contato(nome):
    if nome in informacao:
        print(f"informações do {nome}")
        print(f"numero: {informacao[nome]["numero"]}")
        print(f"E-mail: {informacao[nome]["email"]}")
    else:
        print(f"Contato {nome} não encontrado")


def Listar_contatos():
    print("\nLista de contatos:")
    for nome, info in informacao.items():
        print(f"nome : {nome} , Numero: {info["numero"]} , E-mail: {info["email"]}")

# %%
adicionar_contato("Sabrina", "1603-1998", "sabrina@email.com")
adicionar_contato("Bruno", "1012-1996", "bruno@email.com")
buscar_contato("Bruno")
Listar_contatos()
# Out:
# Sabrina adicionado com sucesso
# Bruno adicionado com sucesso
# informações do Bruno
# numero: 1012-1996
# E-mail: bruno@email.com
#
# Lista de contatos:
# nome : Sabrina , Numero: 1603-1998 , E-mail: sabrina@email.com
# nome : Bruno , Numero: 1012-1996 , E-mail: bruno@email.com

# %%
# PJ 2
tarefas = ["Lavar roupa", "Estudar", "trabalhar"]

def adicionar_terefa(tarefa):
    tarefas.append(tarefa)
    print(f"Tarefa '{tarefa}' adicionada")

def marcar_concluida(tarefa):
    if tarefa in tarefas:
        tarefas.remove(tarefa)
        print(f"Tarefa '{tarefa}' marcada como concluida")
    else:
        print(f"Tarefa '{tarefa}' não encontrada")

def vizualizar_tarefas():
    print("\n Lista de Tarefas:")
    for tarefa in tarefas:
        print(f"-{tarefa}")

# %%
adicionar_terefa("Lavar louças")
marcar_concluida("Lavar roupa")
vizualizar_tarefas()
# Out:
# Tarefa 'Lavar louças' adicionada
# Tarefa 'Lavar roupa' marcada como concluida
#
#  Lista de Tarefas:
# -Estudar
# -trabalhar
# -Lavar louças
